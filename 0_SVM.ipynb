# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, root_mean_squared_error
from sklearn.svm import SVR
import optuna
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

num_trials = 100;

# Load data
shear_strength = pd.read_csv('shear_strength.csv', header=None)
new_or_old = pd.read_csv('new_or_old.csv', header=None)
load_type = pd.read_csv('load_type.csv', header=None)
wall_l = pd.read_csv('wall_l.csv', header=None)
wall_h = pd.read_csv('wall_h.csv', header=None)
wall_t = pd.read_csv('wall_t.csv', header=None)
leaf_num = pd.read_csv('leaf_num.csv', header=None)
bond_pattern = pd.read_csv('bond_pattern.csv', header=None)
ft_mortar = pd.read_csv('ft_mortar.csv', header=None)
ft_brick = pd.read_csv('ft_brick.csv', header=None)

# Combine features and target
X = pd.concat([new_or_old, wall_l, wall_t, leaf_num, bond_pattern, ft_mortar, ft_brick], axis=1)
X.columns = ['new_or_old', 'wall_l', 'wall_t', 'leaf_num', 'bond_pattern', 'ft_mortar', 'ft_brick']
y_raw = shear_strength
y_raw.columns = ['shear_strength']
y = np.log(y_raw)  # log-transform (natural log)
y.columns = ['shear_strength']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=4)

# Scale data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

trial_results = []

# Optuna objective function
def objective(trial):
    C = trial.suggest_float("C", 0.01, 100.0, log=True)
    epsilon = trial.suggest_float("epsilon", 1e-4, 1.0, log=True)
    kernel = trial.suggest_categorical("kernel", ["rbf", "linear", "poly", "sigmoid"])

    if kernel in ["rbf", "poly", "sigmoid"]:
        gamma = trial.suggest_categorical("gamma", ["scale", "auto"])
    else:
        gamma = "scale" 

    model = SVR(
        C=C,
        epsilon=epsilon,
        kernel=kernel,
        gamma=gamma
    )

    cv = KFold(n_splits=10, shuffle=True, random_state=0)
    scores = cross_val_score(model, X_train, y_train.values.ravel(), cv=cv, scoring="neg_mean_squared_error")
    return -scores.mean()

# Run Optuna optimization
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=num_trials)

# Best parameters
print("Best parameters found by Optuna:", study.best_params)

trial_results = sorted(
    [(t.number, t.value, t.params) for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE],
    key=lambda x: x[1]
)[:10] 

print("\nTop 10 Hyperparameter Combinations and Scores:")
for rank, (trial_number, mse, params) in enumerate(trial_results, start=1):
    model = SVR(
        C=params["C"],
        epsilon=params["epsilon"],
        kernel=params["kernel"],
        gamma=params.get("gamma", "scale") 
    )
    
    # Fit model
    model.fit(X_train, y_train.values.ravel())

    y_train_pred_log = model.predict(X_train)
    y_test_pred_log = model.predict(X_test)

    y_train_pred = np.exp(y_train_pred_log)
    y_test_pred = np.exp(y_test_pred_log)

    y_train_np = y_raw.iloc[y_train.index].to_numpy().squeeze()
    y_test_np = y_raw.iloc[y_test.index].to_numpy().squeeze()
    
    # Calculate metrics for training set
    r2_train = r2_score(y_train_np, y_train_pred)
    rmse_train = root_mean_squared_error(y_train_np, y_train_pred)
    ratio_train = y_train_np / y_train_pred
    mean_ratio_train = np.mean(ratio_train)
    cov_ratio_p_train = np.cov(ratio_train, rowvar=False, ddof=1)
    cov_ratio_p_train = cov_ratio_p_train * 100
    
    # Calculate metrics for testing set
    r2_test = r2_score(y_test_np, y_test_pred)
    rmse_test = root_mean_squared_error(y_test_np, y_test_pred)
    ratio_test = y_test_np / y_test_pred
    mean_ratio_test = np.mean(ratio_test)
    cov_ratio_p_test = np.cov(ratio_test, rowvar=False, ddof=1)
    cov_ratio_p_test = cov_ratio_p_test * 100
    
    # Print results
    print(f"Rank {rank}: Trial {trial_number}")
    print(f"Parameters: {params}")
    print(f"Training Set - R²: {r2_train:.3f}, RMSE: {rmse_train:.3f}, mean_ratio: {mean_ratio_train:.3f}, cov_ratio(%): {cov_ratio_p_train:.1f}")
    print(f"Testing Set  - R²: {r2_test:.3f}, RMSE: {rmse_test:.3f}, mean_ratio: {mean_ratio_test:.3f}, cov_ratio(%): {cov_ratio_p_test:.1f}\n")
# Out:
# [I 2025-04-04 10:59:50,955] A new study created in memory with name: no-name-984a073c-866d-40e9-8677-0327003d5cb3
# [I 2025-04-04 10:59:50,994] Trial 0 finished with value: 0.81968629647966 and parameters: {'C': 0.04086299349152498, 'epsilon': 0.005982097225061503, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 0 with value: 0.81968629647966.
# [I 2025-04-04 10:59:51,036] Trial 1 finished with value: 0.8567780522226236 and parameters: {'C': 0.031457624734351576, 'epsilon': 0.1621627513565354, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 0 with value: 0.81968629647966.
# [I 2025-04-04 10:59:51,096] Trial 2 finished with value: 0.7196898254099477 and parameters: {'C': 0.5991165468659588, 'epsilon': 0.0006265452158603236, 'kernel': 'poly', 'gamma': 'auto'}. Best is trial 2 with value: 0.7196898254099477.
# [I 2025-04-04 10:59:51,141] Trial 3 finished with value: 0.4099424119948353 and parameters: {'C': 9.308025095138955, 'epsilon': 0.0014598522209710928, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 3 with value: 0.4099424119948353.
# [I 2025-04-04 10:59:51,209] Trial 4 finished with value: 90.88551250888193 and parameters: {'C': 13.332986037670375, 'epsilon': 0.9918308636846725, 'kernel': 'sigmoid', 'gamma': 'auto'}. Best is trial 3 with value: 0.4099424119948353.
# [I 2025-04-04 10:59:51,266] Trial 5 finished with value: 0.41648206552781286 and parameters: {'C': 0.4806150068341241, 'epsilon': 0.010972599860340148, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 3 with value: 0.4099424119948353.
# [I 2025-04-04 10:59:51,297] Trial 6 finished with value: 0.7140708498292306 and parameters: {'C': 0.023463639392169406, 'epsilon': 0.0010020005671323939, 'kernel': 'poly', 'gamma': 'auto'}. Best is trial 3 with value: 0.4099424119948353.
# [I 2025-04-04 10:59:51,332] Trial 7 finished with value: 0.8015878537771208 and parameters: {'C': 0.011545414047875277, 'epsilon': 0.0004472531131517189, 'kernel': 'poly', 'gamma': 'auto'}. Best is trial 3 with value: 0.4099424119948353.
# [I 2025-04-04 10:59:51,369] Trial 8 finished with value: 0.8005882772463149 and parameters: {'C': 1.1183082296786968, 'epsilon': 0.07638872556152469, 'kernel': 'poly', 'gamma': 'scale'}. Best is trial 3 with value: 0.4099424119948353.
# [I 2025-04-04 10:59:51,427] Trial 9 finished with value: 1.0053086483334133 and parameters: {'C': 0.32930346177309905, 'epsilon': 0.125053579984973, 'kernel': 'sigmoid', 'gamma': 'auto'}. Best is trial 3 with value: 0.4099424119948353.
# [I 2025-04-04 10:59:52,199] Trial 10 finished with value: 1.0460044408472775 and parameters: {'C': 93.09418902867628, 'epsilon': 0.00010240594410375498, 'kernel': 'linear'}. Best is trial 3 with value: 0.4099424119948353.
# [I 2025-04-04 10:59:52,249] Trial 11 finished with value: 0.37904332166658955 and parameters: {'C': 4.983155467124615, 'epsilon': 0.011675765941984577, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 11 with value: 0.37904332166658955.
# [I 2025-04-04 10:59:52,327] Trial 12 finished with value: 0.4103639130360358 and parameters: {'C': 10.531894215680154, 'epsilon': 0.006465606273566759, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 11 with value: 0.37904332166658955.
# [I 2025-04-04 10:59:52,396] Trial 13 finished with value: 0.37421850690970304 and parameters: {'C': 5.279113183777558, 'epsilon': 0.021615331506604857, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 13 with value: 0.37421850690970304.
# [I 2025-04-04 10:59:52,499] Trial 14 finished with value: 1.012262576981894 and parameters: {'C': 2.977842790434314, 'epsilon': 0.03012590558386152, 'kernel': 'linear'}. Best is trial 13 with value: 0.37421850690970304.
# [I 2025-04-04 10:59:52,582] Trial 15 finished with value: 0.7470202765629921 and parameters: {'C': 83.22826868230399, 'epsilon': 0.02143027556330344, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 13 with value: 0.37421850690970304.
# [I 2025-04-04 10:59:52,663] Trial 16 finished with value: 0.369315470934692 and parameters: {'C': 2.7345258889261554, 'epsilon': 0.0040360664492431475, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 16 with value: 0.369315470934692.
# [I 2025-04-04 10:59:52,733] Trial 17 finished with value: 0.6368805977257601 and parameters: {'C': 0.16032943353145013, 'epsilon': 0.0018299056359565127, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 16 with value: 0.369315470934692.
# [I 2025-04-04 10:59:52,823] Trial 18 finished with value: 475.54608194655185 and parameters: {'C': 30.992165331240965, 'epsilon': 0.003401285456972371, 'kernel': 'sigmoid', 'gamma': 'scale'}. Best is trial 16 with value: 0.369315470934692.
# [I 2025-04-04 10:59:52,908] Trial 19 finished with value: 0.9825404298515041 and parameters: {'C': 2.0060195841982194, 'epsilon': 0.42781636117021987, 'kernel': 'linear'}. Best is trial 16 with value: 0.369315470934692.
# [I 2025-04-04 10:59:53,007] Trial 20 finished with value: 0.5172696052586978 and parameters: {'C': 25.661790192884414, 'epsilon': 0.04190394471534232, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 16 with value: 0.369315470934692.
# [I 2025-04-04 10:59:53,060] Trial 21 finished with value: 0.378571219381788 and parameters: {'C': 4.257219821523742, 'epsilon': 0.013269816281599227, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 16 with value: 0.369315470934692.
# [I 2025-04-04 10:59:53,145] Trial 22 finished with value: 0.34903925683311804 and parameters: {'C': 1.7671251567768065, 'epsilon': 0.00390851836966097, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 22 with value: 0.34903925683311804.
# [I 2025-04-04 10:59:53,236] Trial 23 finished with value: 0.3471913119580633 and parameters: {'C': 1.4152558184064867, 'epsilon': 0.0035344982790450844, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:53,330] Trial 24 finished with value: 0.34894105942129444 and parameters: {'C': 1.7346498719846315, 'epsilon': 0.0029215488999534242, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:53,390] Trial 25 finished with value: 0.6643983372057283 and parameters: {'C': 0.13749607612865467, 'epsilon': 0.00032293135112707836, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:53,470] Trial 26 finished with value: 0.3518278058726262 and parameters: {'C': 1.2111909346654819, 'epsilon': 0.002916983696090401, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:53,543] Trial 27 finished with value: 0.884994075504119 and parameters: {'C': 0.214190906892513, 'epsilon': 0.0022217688712055602, 'kernel': 'sigmoid', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:53,644] Trial 28 finished with value: 1.039722162427237 and parameters: {'C': 1.358309115896239, 'epsilon': 0.0001635605464056307, 'kernel': 'linear'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:53,735] Trial 29 finished with value: 0.7409880923308299 and parameters: {'C': 0.08390581111634414, 'epsilon': 0.005813642427067171, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:53,790] Trial 30 finished with value: 0.37847977891495777 and parameters: {'C': 0.7235696023064944, 'epsilon': 0.0009643100992238377, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:53,878] Trial 31 finished with value: 0.34818727669228133 and parameters: {'C': 1.3564037260481756, 'epsilon': 0.002786308703082304, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:53,961] Trial 32 finished with value: 0.34889803805287034 and parameters: {'C': 1.8776047579560686, 'epsilon': 0.00607122947533214, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:54,042] Trial 33 finished with value: 0.4719141687542649 and parameters: {'C': 0.3571077215413855, 'epsilon': 0.008581364219785023, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:54,136] Trial 34 finished with value: 0.37888894739945006 and parameters: {'C': 0.7176035764280627, 'epsilon': 0.0013142464453375713, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:54,189] Trial 35 finished with value: 0.3884385474769171 and parameters: {'C': 6.573873728626671, 'epsilon': 0.006062895180879511, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:54,246] Trial 36 finished with value: 0.3713316798736141 and parameters: {'C': 0.814953822333785, 'epsilon': 0.0007162321694779372, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:54,316] Trial 37 finished with value: 1.1552876172413529 and parameters: {'C': 2.801783863082614, 'epsilon': 0.001842009631865167, 'kernel': 'poly', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:54,415] Trial 38 finished with value: 0.48291755959191834 and parameters: {'C': 19.457553664563193, 'epsilon': 0.0005312852706736522, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:54,465] Trial 39 finished with value: 1.2005499477160129 and parameters: {'C': 0.47069596133006336, 'epsilon': 0.01626433033954317, 'kernel': 'sigmoid', 'gamma': 'auto'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:54,498] Trial 40 finished with value: 0.6410672965424778 and parameters: {'C': 0.06425279066443221, 'epsilon': 0.05554837349915114, 'kernel': 'poly', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:54,587] Trial 41 finished with value: 0.3493166926883326 and parameters: {'C': 1.8647740752935522, 'epsilon': 0.004164060760708324, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:54,671] Trial 42 finished with value: 0.3477342325674825 and parameters: {'C': 1.3899629650603371, 'epsilon': 0.002695321714452458, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:54,751] Trial 43 finished with value: 0.38471842483967345 and parameters: {'C': 3.6144164435499966, 'epsilon': 0.002227382188656719, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:54,843] Trial 44 finished with value: 0.3640837189962904 and parameters: {'C': 1.0076632048857348, 'epsilon': 0.0010477654924395668, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:54,891] Trial 45 finished with value: 0.39160252822753444 and parameters: {'C': 7.34459887564461, 'epsilon': 0.008677212020683694, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:54,972] Trial 46 finished with value: 0.4466094324137259 and parameters: {'C': 0.4052669858813064, 'epsilon': 0.005618901374236435, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:55,047] Trial 47 finished with value: 0.640561935221502 and parameters: {'C': 0.2526502615857228, 'epsilon': 0.00027265675506950364, 'kernel': 'poly', 'gamma': 'auto'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:55,099] Trial 48 finished with value: 1.0370837952787961 and parameters: {'C': 1.5439088346614462, 'epsilon': 0.0025962304246522766, 'kernel': 'linear'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:55,191] Trial 49 finished with value: 0.35966946747814477 and parameters: {'C': 2.340340539200131, 'epsilon': 0.001219635469728209, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:55,246] Trial 50 finished with value: 1.4006125654194357 and parameters: {'C': 0.6033818284202473, 'epsilon': 0.0007394445358973621, 'kernel': 'sigmoid', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:55,333] Trial 51 finished with value: 0.34785858553030974 and parameters: {'C': 1.653570855034782, 'epsilon': 0.004170846988908178, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:55,385] Trial 52 finished with value: 0.35148748998752327 and parameters: {'C': 1.1991291309680496, 'epsilon': 0.008417281835914836, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:55,432] Trial 53 finished with value: 0.3777744799084052 and parameters: {'C': 3.0944722288269637, 'epsilon': 0.0034721655832550863, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:55,510] Trial 54 finished with value: 0.3639536389582963 and parameters: {'C': 0.944642368171131, 'epsilon': 0.0015529579718494856, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:55,594] Trial 55 finished with value: 0.386979295484516 and parameters: {'C': 4.858632522883343, 'epsilon': 0.0046805940291136505, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:55,689] Trial 56 finished with value: 0.41235436981857293 and parameters: {'C': 11.578656806942018, 'epsilon': 0.011307958821554446, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:55,772] Trial 57 finished with value: 0.34871107102000687 and parameters: {'C': 2.0408286636724675, 'epsilon': 0.020167470908276888, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:55,836] Trial 58 finished with value: 1.018304288873779 and parameters: {'C': 2.4369574441585797, 'epsilon': 0.023694078468412386, 'kernel': 'linear'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:55,934] Trial 59 finished with value: 0.38862523352794953 and parameters: {'C': 7.3315891826264625, 'epsilon': 0.01779052057905926, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:56,009] Trial 60 finished with value: 0.7056498164358003 and parameters: {'C': 0.47747821326930856, 'epsilon': 0.037701030632455716, 'kernel': 'poly', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:56,105] Trial 61 finished with value: 0.3481989489627107 and parameters: {'C': 1.6486506523543443, 'epsilon': 0.0027682143640301617, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:56,184] Trial 62 finished with value: 0.38208345729844717 and parameters: {'C': 4.025543675210187, 'epsilon': 0.007152339142503702, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 23 with value: 0.3471913119580633.
# [I 2025-04-04 10:59:56,274] Trial 63 finished with value: 0.33476268893071925 and parameters: {'C': 1.5139663948074236, 'epsilon': 0.16259922229457582, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:56,348] Trial 64 finished with value: 0.36452467119968696 and parameters: {'C': 0.9630093592748167, 'epsilon': 0.2832517198014687, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:56,439] Trial 65 finished with value: 0.33647306786418196 and parameters: {'C': 1.2359257054493393, 'epsilon': 0.1041421874570477, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:56,516] Trial 66 finished with value: 0.33626160826228735 and parameters: {'C': 1.4324204064174535, 'epsilon': 0.17176991241543463, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:56,567] Trial 67 finished with value: 1.3345086131431736 and parameters: {'C': 0.5971361370852174, 'epsilon': 0.12069975603568998, 'kernel': 'sigmoid', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:56,607] Trial 68 finished with value: 0.34793949833425863 and parameters: {'C': 1.274783971848266, 'epsilon': 0.27512823194417835, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:56,697] Trial 69 finished with value: 0.6101723182000703 and parameters: {'C': 0.2637818109426606, 'epsilon': 0.8130164563644584, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:56,779] Trial 70 finished with value: 0.3626130002005305 and parameters: {'C': 0.7867151482085888, 'epsilon': 0.22698631538108643, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:56,821] Trial 71 finished with value: 0.33620963207814614 and parameters: {'C': 1.253250216905487, 'epsilon': 0.11587168312861032, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:56,911] Trial 72 finished with value: 0.3379974410459051 and parameters: {'C': 1.123075731169283, 'epsilon': 0.09751868388977725, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:56,988] Trial 73 finished with value: 0.35792403001651546 and parameters: {'C': 3.2596477690726444, 'epsilon': 0.0787149356986254, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:57,084] Trial 74 finished with value: 0.38493719673973437 and parameters: {'C': 0.6098875301052765, 'epsilon': 0.11900820620313037, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:57,156] Trial 75 finished with value: 0.7127399962332148 and parameters: {'C': 0.019296052112807115, 'epsilon': 0.19379636684796675, 'kernel': 'linear'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:57,239] Trial 76 finished with value: 0.3388241852970995 and parameters: {'C': 1.1074443018132876, 'epsilon': 0.07685617877782606, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:57,334] Trial 77 finished with value: 0.344506528142288 and parameters: {'C': 0.943998832317807, 'epsilon': 0.0853260589334364, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:57,416] Trial 78 finished with value: 0.3405466096396027 and parameters: {'C': 1.0387798074559829, 'epsilon': 0.08326032701868769, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:57,490] Trial 79 finished with value: 0.3452043620065509 and parameters: {'C': 0.9361077709321357, 'epsilon': 0.08309356922478803, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:57,576] Trial 80 finished with value: 0.37662635274530387 and parameters: {'C': 0.6755745237155603, 'epsilon': 0.05977782190962392, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:57,651] Trial 81 finished with value: 0.34209994235249774 and parameters: {'C': 0.9705351023216868, 'epsilon': 0.09184675452033801, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:57,735] Trial 82 finished with value: 0.3414365770600818 and parameters: {'C': 1.0899026156434932, 'epsilon': 0.15420153151178556, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:57,806] Trial 83 finished with value: 0.3359680294376748 and parameters: {'C': 2.1660966175726264, 'epsilon': 0.17147261093211327, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:57,871] Trial 84 finished with value: 0.3386900933313683 and parameters: {'C': 2.2693665880044964, 'epsilon': 0.14568549632441763, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:57,954] Trial 85 finished with value: 0.41223248805104856 and parameters: {'C': 2.7834271535534567, 'epsilon': 0.5675890753664318, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:58,030] Trial 86 finished with value: 4.110378461634085 and parameters: {'C': 2.0987755707841997, 'epsilon': 0.39847161418505567, 'kernel': 'sigmoid', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:58,131] Trial 87 finished with value: 1.781429556361853 and parameters: {'C': 4.819824138143868, 'epsilon': 0.06069513110336993, 'kernel': 'poly', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:58,206] Trial 88 finished with value: 0.34150949431358035 and parameters: {'C': 2.629872940695718, 'epsilon': 0.14790874873725635, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:58,256] Trial 89 finished with value: 0.4735262872985778 and parameters: {'C': 0.3488458654956185, 'epsilon': 0.0456248432929479, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:58,343] Trial 90 finished with value: 0.36743836735464025 and parameters: {'C': 5.910530737755503, 'epsilon': 0.10429902490627393, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:58,402] Trial 91 finished with value: 0.3411531083792276 and parameters: {'C': 1.125268716451071, 'epsilon': 0.16424641752656277, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:58,434] Trial 92 finished with value: 0.33677724275393994 and parameters: {'C': 1.4567146187242586, 'epsilon': 0.21635712825267767, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:58,527] Trial 93 finished with value: 0.35982909527097434 and parameters: {'C': 1.5446128417288116, 'epsilon': 0.34990433332424803, 'kernel': 'rbf', 'gamma': 'scale'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:58,606] Trial 94 finished with value: 0.3401622901183542 and parameters: {'C': 2.167115850031453, 'epsilon': 0.1729475781606241, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:58,691] Trial 95 finished with value: 0.34308508013011374 and parameters: {'C': 2.1688479272122074, 'epsilon': 0.23182136980413262, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:58,773] Trial 96 finished with value: 0.336749253460345 and parameters: {'C': 3.3101931361484906, 'epsilon': 0.17023692847359218, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:58,873] Trial 97 finished with value: 0.9057326295211734 and parameters: {'C': 3.700812784254436, 'epsilon': 0.2200625245233862, 'kernel': 'linear'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:58,945] Trial 98 finished with value: 0.33720631819196184 and parameters: {'C': 1.3627701088883704, 'epsilon': 0.1308816931015144, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 63 with value: 0.33476268893071925.
# [I 2025-04-04 10:59:59,037] Trial 99 finished with value: 0.3398349853171195 and parameters: {'C': 1.7743194755637046, 'epsilon': 0.13495182456264346, 'kernel': 'rbf', 'gamma': 'auto'}. Best is trial 63 with value: 0.33476268893071925.
# Best parameters found by Optuna: {'C': 1.5139663948074236, 'epsilon': 0.16259922229457582, 'kernel': 'rbf', 'gamma': 'scale'}
#
# Top 10 Hyperparameter Combinations and Scores:
# Rank 1: Trial 63
# Parameters: {'C': 1.5139663948074236, 'epsilon': 0.16259922229457582, 'kernel': 'rbf', 'gamma': 'scale'}
# Training Set - R²: 0.878, RMSE: 0.152, mean_ratio: 1.077, cov_ratio(%): 19.6
# Testing Set  - R²: 0.820, RMSE: 0.196, mean_ratio: 1.080, cov_ratio(%): 22.5
#
# Rank 2: Trial 83
# Parameters: {'C': 2.1660966175726264, 'epsilon': 0.17147261093211327, 'kernel': 'rbf', 'gamma': 'scale'}
# Training Set - R²: 0.883, RMSE: 0.149, mean_ratio: 1.089, cov_ratio(%): 20.0
# Testing Set  - R²: 0.819, RMSE: 0.197, mean_ratio: 1.108, cov_ratio(%): 26.7
#
# Rank 3: Trial 71
# Parameters: {'C': 1.253250216905487, 'epsilon': 0.11587168312861032, 'kernel': 'rbf', 'gamma': 'scale'}
# Training Set - R²: 0.875, RMSE: 0.154, mean_ratio: 1.062, cov_ratio(%): 21.1
# Testing Set  - R²: 0.827, RMSE: 0.193, mean_ratio: 1.049, cov_ratio(%): 19.1
#
# Rank 4: Trial 66
# Parameters: {'C': 1.4324204064174535, 'epsilon': 0.17176991241543463, 'kernel': 'rbf', 'gamma': 'scale'}
# Training Set - R²: 0.876, RMSE: 0.154, mean_ratio: 1.076, cov_ratio(%): 19.6
# Testing Set  - R²: 0.818, RMSE: 0.198, mean_ratio: 1.076, cov_ratio(%): 21.7
#
# Rank 5: Trial 65
# Parameters: {'C': 1.2359257054493393, 'epsilon': 0.1041421874570477, 'kernel': 'rbf', 'gamma': 'scale'}
# Training Set - R²: 0.874, RMSE: 0.155, mean_ratio: 1.061, cov_ratio(%): 21.5
# Testing Set  - R²: 0.828, RMSE: 0.192, mean_ratio: 1.045, cov_ratio(%): 18.8
#
# Rank 6: Trial 96
# Parameters: {'C': 3.3101931361484906, 'epsilon': 0.17023692847359218, 'kernel': 'rbf', 'gamma': 'auto'}
# Training Set - R²: 0.885, RMSE: 0.148, mean_ratio: 1.098, cov_ratio(%): 22.5
# Testing Set  - R²: 0.811, RMSE: 0.202, mean_ratio: 1.138, cov_ratio(%): 36.3
#
# Rank 7: Trial 92
# Parameters: {'C': 1.4567146187242586, 'epsilon': 0.21635712825267767, 'kernel': 'rbf', 'gamma': 'scale'}
# Training Set - R²: 0.864, RMSE: 0.161, mean_ratio: 1.080, cov_ratio(%): 19.6
# Testing Set  - R²: 0.806, RMSE: 0.204, mean_ratio: 1.084, cov_ratio(%): 22.4
#
# Rank 8: Trial 98
# Parameters: {'C': 1.3627701088883704, 'epsilon': 0.1308816931015144, 'kernel': 'rbf', 'gamma': 'auto'}
# Training Set - R²: 0.877, RMSE: 0.153, mean_ratio: 1.068, cov_ratio(%): 20.4
# Testing Set  - R²: 0.825, RMSE: 0.194, mean_ratio: 1.061, cov_ratio(%): 20.5
#
# Rank 9: Trial 72
# Parameters: {'C': 1.123075731169283, 'epsilon': 0.09751868388977725, 'kernel': 'rbf', 'gamma': 'scale'}
# Training Set - R²: 0.867, RMSE: 0.159, mean_ratio: 1.064, cov_ratio(%): 22.3
# Testing Set  - R²: 0.824, RMSE: 0.194, mean_ratio: 1.047, cov_ratio(%): 18.6
#
# Rank 10: Trial 84
# Parameters: {'C': 2.2693665880044964, 'epsilon': 0.14568549632441763, 'kernel': 'rbf', 'gamma': 'scale'}
# Training Set - R²: 0.888, RMSE: 0.146, mean_ratio: 1.082, cov_ratio(%): 20.1
# Testing Set  - R²: 0.823, RMSE: 0.195, mean_ratio: 1.104, cov_ratio(%): 27.6
