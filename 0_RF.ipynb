# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, root_mean_squared_error
from sklearn.ensemble import RandomForestRegressor
import optuna
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

num_trials = 100;

# Load data
shear_strength = pd.read_csv('shear_strength.csv', header=None)
new_or_old = pd.read_csv('new_or_old.csv', header=None)
load_type = pd.read_csv('load_type.csv', header=None)
wall_l = pd.read_csv('wall_l.csv', header=None)
wall_h = pd.read_csv('wall_h.csv', header=None)
wall_t = pd.read_csv('wall_t.csv', header=None)
leaf_num = pd.read_csv('leaf_num.csv', header=None)
bond_pattern = pd.read_csv('bond_pattern.csv', header=None)
ft_mortar = pd.read_csv('ft_mortar.csv', header=None)
ft_brick = pd.read_csv('ft_brick.csv', header=None)

# Combine features and target
X = pd.concat([new_or_old, wall_l, wall_t, leaf_num, bond_pattern, ft_mortar, ft_brick], axis=1)
X.columns = ['new_or_old', 'wall_l', 'wall_t', 'leaf_num', 'bond_pattern', 'ft_mortar', 'ft_brick']
y_raw = shear_strength 
y_raw.columns = ['shear_strength']
y = np.log(y_raw)  # log-transform (natural log)
y.columns = ['shear_strength']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=4)

# Scale data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

trial_results = []

# Optuna objective function
def objective(trial):
    n_estimators = trial.suggest_int("n_estimators", 50, 1000)
    max_depth = trial.suggest_int("max_depth", 2, 200)
    min_samples_split = trial.suggest_int("min_samples_split", 2, 20)
    min_samples_leaf = trial.suggest_int("min_samples_leaf", 1, 20)
    max_features = trial.suggest_categorical("max_features", ["sqrt", "log2", None])
    bootstrap = trial.suggest_categorical("bootstrap", [True, False])
    
    model = RandomForestRegressor(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        bootstrap=bootstrap,
        random_state=0,
        n_jobs=-1
    )

    cv = KFold(n_splits=10, shuffle=True, random_state=0)
    scores = cross_val_score(model, X_train, y_train.values.ravel(), cv=cv, scoring="neg_mean_squared_error")
    return -scores.mean()

# Run Optuna optimization
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=num_trials)

# Best parameters
print("Best parameters found by Optuna:", study.best_params)

trial_results = sorted(
    [(t.number, t.value, t.params) for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE],
    key=lambda x: x[1]
)[:10] 

print("\nTop 10 Hyperparameter Combinations and Scores:")
for rank, (trial_number, mse, params) in enumerate(trial_results, start=1):
    model = RandomForestRegressor(
        n_estimators=params["n_estimators"],
        max_depth=params["max_depth"],
        min_samples_split=params["min_samples_split"],
        min_samples_leaf=params["min_samples_leaf"],
        max_features=params["max_features"],
        bootstrap=params["bootstrap"],
        random_state=0,
        n_jobs=-1
    )
    
    model.fit(X_train, y_train.values.ravel())

    y_train_pred_log = model.predict(X_train)
    y_test_pred_log = model.predict(X_test)

    y_train_pred = np.exp(y_train_pred_log)
    y_test_pred = np.exp(y_test_pred_log)

    y_train_np = y_raw.iloc[y_train.index].to_numpy().squeeze()
    y_test_np = y_raw.iloc[y_test.index].to_numpy().squeeze()
    
    # Calculate metrics for training set
    r2_train = r2_score(y_train_np, y_train_pred)
    rmse_train = root_mean_squared_error(y_train_np, y_train_pred)
    ratio_train = y_train_np / y_train_pred
    mean_ratio_train = np.mean(ratio_train)
    cov_ratio_p_train = np.cov(ratio_train, rowvar=False, ddof=1)
    cov_ratio_p_train = cov_ratio_p_train * 100
    
    # Calculate metrics for testing set
    r2_test = r2_score(y_test_np, y_test_pred)
    rmse_test = root_mean_squared_error(y_test_np, y_test_pred)
    ratio_test = y_test_np / y_test_pred
    mean_ratio_test = np.mean(ratio_test)
    cov_ratio_p_test = np.cov(ratio_test, rowvar=False, ddof=1)
    cov_ratio_p_test = cov_ratio_p_test * 100
    
    # Print results
    print(f"Rank {rank}: Trial {trial_number}")
    print(f"Parameters: {params}")
    print(f"Training Set - R²: {r2_train:.3f}, RMSE: {rmse_train:.3f}, mean_ratio: {mean_ratio_train:.3f}, cov_ratio(%): {cov_ratio_p_train:.1f}")
    print(f"Testing Set  - R²: {r2_test:.3f}, RMSE: {rmse_test:.3f}, mean_ratio: {mean_ratio_test:.3f}, cov_ratio(%): {cov_ratio_p_test:.1f}\n")
# Out:
# [I 2025-04-03 19:52:22,372] A new study created in memory with name: no-name-e0c3edd4-d35b-43dc-83bf-5b092bf7b70d
# [I 2025-04-03 19:52:36,025] Trial 0 finished with value: 0.4563899377150912 and parameters: {'n_estimators': 779, 'max_depth': 128, 'min_samples_split': 13, 'min_samples_leaf': 9, 'max_features': None, 'bootstrap': True}. Best is trial 0 with value: 0.4563899377150912.
# [I 2025-04-03 19:52:48,303] Trial 1 finished with value: 0.4990271941396151 and parameters: {'n_estimators': 639, 'max_depth': 128, 'min_samples_split': 6, 'min_samples_leaf': 13, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 0 with value: 0.4563899377150912.
# [I 2025-04-03 19:53:04,064] Trial 2 finished with value: 0.4725973170701934 and parameters: {'n_estimators': 895, 'max_depth': 20, 'min_samples_split': 19, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 0 with value: 0.4563899377150912.
# [I 2025-04-03 19:53:13,813] Trial 3 finished with value: 0.3956233724786093 and parameters: {'n_estimators': 563, 'max_depth': 128, 'min_samples_split': 14, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 3 with value: 0.3956233724786093.
# [I 2025-04-03 19:53:22,232] Trial 4 finished with value: 0.37784034859450827 and parameters: {'n_estimators': 487, 'max_depth': 174, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 4 with value: 0.37784034859450827.
# [I 2025-04-03 19:53:34,025] Trial 5 finished with value: 0.45094094639124577 and parameters: {'n_estimators': 647, 'max_depth': 142, 'min_samples_split': 12, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': False}. Best is trial 4 with value: 0.37784034859450827.
# [I 2025-04-03 19:53:44,757] Trial 6 finished with value: 0.7629052310777356 and parameters: {'n_estimators': 636, 'max_depth': 106, 'min_samples_split': 3, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 4 with value: 0.37784034859450827.
# [I 2025-04-03 19:53:51,290] Trial 7 finished with value: 0.6495698155115266 and parameters: {'n_estimators': 369, 'max_depth': 63, 'min_samples_split': 13, 'min_samples_leaf': 18, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 4 with value: 0.37784034859450827.
# [I 2025-04-03 19:54:08,669] Trial 8 finished with value: 0.6736588287242519 and parameters: {'n_estimators': 982, 'max_depth': 54, 'min_samples_split': 16, 'min_samples_leaf': 15, 'max_features': None, 'bootstrap': True}. Best is trial 4 with value: 0.37784034859450827.
# [I 2025-04-03 19:54:12,059] Trial 9 finished with value: 0.3290777499726982 and parameters: {'n_estimators': 152, 'max_depth': 68, 'min_samples_split': 12, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': False}. Best is trial 9 with value: 0.3290777499726982.
# [I 2025-04-03 19:54:13,665] Trial 10 finished with value: 0.3570181821686812 and parameters: {'n_estimators': 64, 'max_depth': 68, 'min_samples_split': 9, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True}. Best is trial 9 with value: 0.3290777499726982.
# [I 2025-04-03 19:54:15,294] Trial 11 finished with value: 0.3567749424904793 and parameters: {'n_estimators': 62, 'max_depth': 72, 'min_samples_split': 9, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True}. Best is trial 9 with value: 0.3290777499726982.
# [I 2025-04-03 19:54:17,106] Trial 12 finished with value: 0.3562167525857887 and parameters: {'n_estimators': 63, 'max_depth': 19, 'min_samples_split': 9, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True}. Best is trial 9 with value: 0.3290777499726982.
# [I 2025-04-03 19:54:21,728] Trial 13 finished with value: 0.5036495836906785 and parameters: {'n_estimators': 240, 'max_depth': 2, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': True}. Best is trial 9 with value: 0.3290777499726982.
# [I 2025-04-03 19:54:26,283] Trial 14 finished with value: 0.49427596509043636 and parameters: {'n_estimators': 226, 'max_depth': 33, 'min_samples_split': 16, 'min_samples_leaf': 12, 'max_features': 'log2', 'bootstrap': False}. Best is trial 9 with value: 0.3290777499726982.
# [I 2025-04-03 19:54
 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 62 with value: 0.2457787599045021.
# [I 2025-04-03 20:09:46,343] Trial 86 finished with value: 0.48402756288744814 and parameters: {'n_estimators': 866, 'max_depth': 24, 'min_samples_split': 5, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 62 with value: 0.2457787599045021.
# [I 2025-04-03 20:10:03,363] Trial 87 finished with value: 0.33114712371380406 and parameters: {'n_estimators': 966, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 62 with value: 0.2457787599045021.
# [I 2025-04-03 20:10:18,932] Trial 88 finished with value: 0.359174385793386 and parameters: {'n_estimators': 896, 'max_depth': 38, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 62 with value: 0.2457787599045021.
# [I 2025-04-03 20:10:35,543] Trial 89 finished with value: 0.4488763113256251 and parameters: {'n_estimators': 974, 'max_depth': 46, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 62 with value: 0.2457787599045021.
# [I 2025-04-03 20:10:47,824] Trial 90 finished with value: 0.3040795492957479 and parameters: {'n_estimators': 768, 'max_depth': 62, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 62 with value: 0.2457787599045021.
# [I 2025-04-03 20:11:04,863] Trial 91 finished with value: 0.24760880030252622 and parameters: {'n_estimators': 976, 'max_depth': 53, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 62 with value: 0.2457787599045021.
# [I 2025-04-03 20:11:21,001] Trial 92 finished with value: 0.24766156016410873 and parameters: {'n_estimators': 951, 'max_depth': 51, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 62 with value: 0.2457787599045021.
# [I 2025-04-03 20:11:37,132] Trial 93 finished with value: 0.25885290092706736 and parameters: {'n_estimators': 933, 'max_depth': 51, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 62 with value: 0.2457787599045021.
# [I 2025-04-03 20:11:53,882] Trial 94 finished with value: 0.25604361395712116 and parameters: {'n_estimators': 950, 'max_depth': 30, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 62 with value: 0.2457787599045021.
# [I 2025-04-03 20:12:09,195] Trial 95 finished with value: 0.2559918229613602 and parameters: {'n_estimators': 904, 'max_depth': 40, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 62 with value: 0.2457787599045021.
# [I 2025-04-03 20:12:26,044] Trial 96 finished with value: 0.25817992905917775 and parameters: {'n_estimators': 960, 'max_depth': 48, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 62 with value: 0.2457787599045021.
# [I 2025-04-03 20:12:28,350] Trial 97 finished with value: 0.7857104826500823 and parameters: {'n_estimators': 100, 'max_depth': 53, 'min_samples_split': 8, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 62 with value: 0.2457787599045021.
# [I 2025-04-03 20:12:41,699] Trial 98 finished with value: 0.24766757840495401 and parameters: {'n_estimators': 826, 'max_depth': 55, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 62 with value: 0.2457787599045021.
# [I 2025-04-03 20:12:55,604] Trial 99 finished with value: 0.3061848023539323 and parameters: {'n_estimators': 826, 'max_depth': 71, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 62 with value: 0.2457787599045021.
# Best parameters found by Optuna: {'n_estimators': 981, 'max_depth': 38, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False}
#
# Top 10 Hyperparameter Combinations and Scores:
# Rank 1: Trial 62
# Parameters: {'n_estimators': 981, 'max_depth': 38, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False}
# Training Set - R²: 0.947, RMSE: 0.100, mean_ratio: 1.011, cov_ratio(%): 2.3
# Testing Set  - R²: 0.874, RMSE: 0.164, mean_ratio: 1.041, cov_ratio(%): 15.1
#
# Rank 2: Trial 61
# Parameters: {'n_estimators': 988, 'max_depth': 43, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False}
# Training Set - R²: 0.947, RMSE: 0.100, mean_ratio: 1.011, cov_ratio(%): 2.3
# Testing Set  - R²: 0.874, RMSE: 0.164, mean_ratio: 1.042, cov_ratio(%): 15.1
#
# Rank 3: Trial 64
# Parameters: {'n_estimators': 998, 'max_depth': 45, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False}
# Training Set - R²: 0.936, RMSE: 0.110, mean_ratio: 1.016, cov_ratio(%): 3.3
# Testing Set  - R²: 0.875, RMSE: 0.164, mean_ratio: 1.039, cov_ratio(%): 14.2
#
# Rank 4: Trial 72
# Parameters: {'n_estimators': 922, 'max_depth': 62, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False}
# Training Set - R²: 0.936, RMSE: 0.110, mean_ratio: 1.016, cov_ratio(%): 3.3
# Testing Set  - R²: 0.875, RMSE: 0.164, mean_ratio: 1.039, cov_ratio(%): 14.3
#
# Rank 5: Trial 75
# Parameters: {'n_estimators': 971, 'max_depth': 52, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False}
# Training Set - R²: 0.936, RMSE: 0.110, mean_ratio: 1.016, cov_ratio(%): 3.3
# Testing Set  - R²: 0.875, RMSE: 0.164, mean_ratio: 1.039, cov_ratio(%): 14.3
#
# Rank 6: Trial 63
# Parameters: {'n_estimators': 981, 'max_depth': 44, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False}
# Training Set - R²: 0.937, RMSE: 0.110, mean_ratio: 1.016, cov_ratio(%): 3.3
# Testing Set  - R²: 0.875, RMSE: 0.164, mean_ratio: 1.039, cov_ratio(%): 14.3
#
# Rank 7: Trial 91
# Parameters: {'n_estimators': 976, 'max_depth': 53, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False}
# Training Set - R²: 0.936, RMSE: 0.110, mean_ratio: 1.016, cov_ratio(%): 3.3
# Testing Set  - R²: 0.875, RMSE: 0.164, mean_ratio: 1.039, cov_ratio(%): 14.3
#
# Rank 8: Trial 92
# Parameters: {'n_estimators': 951, 'max_depth': 51, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False}
# Training Set - R²: 0.936, RMSE: 0.110, mean_ratio: 1.016, cov_ratio(%): 3.3
# Testing Set  - R²: 0.875, RMSE: 0.164, mean_ratio: 1.039, cov_ratio(%): 14.3
#
# Rank 9: Trial 98
# Parameters: {'n_estimators': 826, 'max_depth': 55, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False}
# Training Set - R²: 0.937, RMSE: 0.110, mean_ratio: 1.016, cov_ratio(%): 3.3
# Testing Set  - R²: 0.875, RMSE: 0.164, mean_ratio: 1.040, cov_ratio(%): 14.3
#
# Rank 10: Trial 81
# Parameters: {'n_estimators': 944, 'max_depth': 66, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False}
# Training Set - R²: 0.936, RMSE: 0.110, mean_ratio: 1.016, cov_ratio(%): 3.3
# Testing Set  - R²: 0.875, RMSE: 0.164, mean_ratio: 1.039, cov_ratio(%): 14.2
