# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, root_mean_squared_error
from sklearn.tree import DecisionTreeRegressor
import optuna
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

num_trials = 100;

# Load data
shear_strength = pd.read_csv('shear_strength.csv', header=None)
new_or_old = pd.read_csv('new_or_old.csv', header=None)
load_type = pd.read_csv('load_type.csv', header=None)
wall_l = pd.read_csv('wall_l.csv', header=None)
wall_h = pd.read_csv('wall_h.csv', header=None)
wall_t = pd.read_csv('wall_t.csv', header=None)
leaf_num = pd.read_csv('leaf_num.csv', header=None)
bond_pattern = pd.read_csv('bond_pattern.csv', header=None)
ft_mortar = pd.read_csv('ft_mortar.csv', header=None)
ft_brick = pd.read_csv('ft_brick.csv', header=None)

# Combine features and target
X = pd.concat([new_or_old, wall_l, wall_t, leaf_num, bond_pattern, ft_mortar, ft_brick], axis=1)
X.columns = ['new_or_old', 'wall_l', 'wall_t', 'leaf_num', 'bond_pattern', 'ft_mortar', 'ft_brick']
y_raw = shear_strength
y_raw.columns = ['shear_strength']
y = np.log(y_raw)  # log-transform (natural log)
y.columns = ['shear_strength']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=4)

# Scale data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

trial_results = []

# Optuna objective function
def objective(trial):
    max_depth = trial.suggest_int("max_depth", 1, 200)
    min_samples_split = trial.suggest_int("min_samples_split", 2, 20)
    min_samples_leaf = trial.suggest_int("min_samples_leaf", 1, 20)
    max_features = trial.suggest_categorical("max_features", ["sqrt", "log2", None])
    
    model = DecisionTreeRegressor(
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        random_state=0
    )

    cv = KFold(n_splits=10, shuffle=True, random_state=0)
    scores = cross_val_score(model, X_train, y_train.values.ravel(), cv=cv, scoring="neg_mean_squared_error")
    return -scores.mean()

# Run Optuna optimization
sampler = optuna.samplers.TPESampler(seed=5)
study = optuna.create_study(direction="minimize", sampler=sampler)
study.optimize(objective, n_trials=num_trials)

# Best parameters
print("Best parameters found by Optuna:", study.best_params)

trial_results = sorted(
    [(t.number, t.value, t.params) for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE],
    key=lambda x: x[1]
)[:10] 

print("\nTop 10 Hyperparameter Combinations and Scores:")
for rank, (trial_number, mse, params) in enumerate(trial_results, start=1):
    model = DecisionTreeRegressor(
        max_depth=params["max_depth"],
        min_samples_split=params["min_samples_split"],
        min_samples_leaf=params["min_samples_leaf"],
        max_features=params["max_features"],
        random_state=0
    )
    
    model.fit(X_train, y_train.values.ravel())

    y_train_pred_log = model.predict(X_train)
    y_test_pred_log = model.predict(X_test)

    y_train_pred = np.exp(y_train_pred_log)
    y_test_pred = np.exp(y_test_pred_log)

    y_train_np = y_raw.iloc[y_train.index].to_numpy().squeeze()
    y_test_np = y_raw.iloc[y_test.index].to_numpy().squeeze()
    
    # Calculate metrics for training set
    r2_train = r2_score(y_train_np, y_train_pred)
    rmse_train = root_mean_squared_error(y_train_np, y_train_pred)
    ratio_train = y_train_np / y_train_pred
    mean_ratio_train = np.mean(ratio_train)
    cov_ratio_p_train = np.cov(ratio_train, rowvar=False, ddof=1)
    cov_ratio_p_train = cov_ratio_p_train * 100
    
    # Calculate metrics for testing set
    r2_test = r2_score(y_test_np, y_test_pred)
    rmse_test = root_mean_squared_error(y_test_np, y_test_pred)
    ratio_test = y_test_np / y_test_pred
    mean_ratio_test = np.mean(ratio_test)
    cov_ratio_p_test = np.cov(ratio_test, rowvar=False, ddof=1)
    cov_ratio_p_test = cov_ratio_p_test * 100
    
    # Print results
    print(f"Rank {rank}: Trial {trial_number}")
    print(f"Parameters: {params}")
    print(f"Training Set - R²: {r2_train:.3f}, RMSE: {rmse_train:.3f}, mean_ratio: {mean_ratio_train:.3f}, cov_ratio(%): {cov_ratio_p_train:.1f}")
    print(f"Testing Set  - R²: {r2_test:.3f}, RMSE: {rmse_test:.3f}, mean_ratio: {mean_ratio_test:.3f}, cov_ratio(%): {cov_ratio_p_test:.1f}\n")
# Out:
# [I 2025-04-14 10:09:28,896] A new study created in memory with name: no-name-0e50e6f1-a748-4282-8b30-e00c0dcc7f98
# [I 2025-04-14 10:09:28,931] Trial 0 finished with value: 0.5207411564829705 and parameters: {'max_depth': 45, 'min_samples_split': 18, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.5207411564829705.
# [I 2025-04-14 10:09:28,978] Trial 1 finished with value: 0.5097781504669585 and parameters: {'max_depth': 154, 'min_samples_split': 11, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 1 with value: 0.5097781504669585.
# [I 2025-04-14 10:09:29,025] Trial 2 finished with value: 0.7754149488454439 and parameters: {'max_depth': 89, 'min_samples_split': 5, 'min_samples_leaf': 18, 'max_features': 'log2'}. Best is trial 1 with value: 0.5097781504669585.
# [I 2025-04-14 10:09:29,080] Trial 3 finished with value: 0.5830570601450449 and parameters: {'max_depth': 126, 'min_samples_split': 13, 'min_samples_leaf': 12, 'max_features': 'log2'}. Best is trial 1 with value: 0.5097781504669585.
# [I 2025-04-14 10:09:29,128] Trial 4 finished with value: 0.5260108891889291 and parameters: {'max_depth': 66, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.5097781504669585.
# [I 2025-04-14 10:09:29,159] Trial 5 finished with value: 0.5853164500741665 and parameters: {'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 14, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.5097781504669585.
# [I 2025-04-14 10:09:29,181] Trial 6 finished with value: 0.7754149488454439 and parameters: {'max_depth': 1, 'min_samples_split': 11, 'min_samples_leaf': 13, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.5097781504669585.
# [I 2025-04-14 10:09:29,220] Trial 7 finished with value: 0.5052049203800777 and parameters: {'max_depth': 175, 'min_samples_split': 19, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 7 with value: 0.5052049203800777.
# [I 2025-04-14 10:09:29,244] Trial 8 finished with value: 0.6844038786005657 and parameters: {'max_depth': 163, 'min_samples_split': 12, 'min_samples_leaf': 16, 'max_features': 'sqrt'}. Best is trial 7 with value: 0.5052049203800777.
# [I 2025-04-14 10:09:29,287] Trial 9 finished with value: 0.8764931798020582 and parameters: {'max_depth': 23, 'min_samples_split': 6, 'min_samples_leaf': 20, 'max_features': 'log2'}. Best is trial 7 with value: 0.5052049203800777.
# [I 2025-04-14 10:09:29,395] Trial 10 finished with value: 0.4639937741776536 and parameters: {'max_depth': 199, 'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 10 with value: 0.4639937741776536.
# [I 2025-04-14 10:09:29,484] Trial 11 finished with value: 0.4639937741776536 and parameters: {'max_depth': 200, 'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 10 with value: 0.4639937741776536.
# [I 2025-04-14 10:09:29,575] Trial 12 finished with value: 0.43316182188487423 and parameters: {'max_depth': 197, 'min_samples_split': 16, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 12 with value: 0.43316182188487423.
# [I 2025-04-14 10:09:29,686] Trial 13 finished with value: 0.45059624836267503 and parameters: {'max_depth': 194, 'min_samples_split': 16, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 12 with value: 0.43316182188487423.
# [I 2025-04-14 10:09:29,771] Trial 14 finished with value: 0.4629962512675056 and parameters: {'max_depth': 131, 'min_samples_split': 16, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 12 with value: 0.43316182188487423.
# [I 2025-04-14 10:09:29,855] Trial 15 finished with value: 0.4629962512675056 and parameters: {'max_depth': 124, 'min_samples_split': 15, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 12 with value: 0.43316182188487423.
# [I 2025-04-14 10:09:29,928] Trial 16 finished with value: 0.4466489365344146 and parameters: {'max_depth': 179, 'min_samples_split': 16, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 12 with value: 0.43316182188487423.
# [I 2025-04-14 10:09:30,024] Trial 17 finished with value: 0.5668286718837744 and parameters: {'max_depth': 146, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 12 with value: 0.43316182188487423.
# [I 2025-04-14 10:09:30,110] Trial 18 finished with value: 0.4476717046799439 and parameters: {'max_depth': 179, 'min_samples_split': 14, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 12 with value: 0.43316182188487423.
# [I 2025-04-14 10:09:30,204] Trial 19 finished with value: 0.5515352555566693 and parameters: {'max_depth': 103, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 12 with value: 0.43316182188487423.
# [I 2025-04-14 10:09:30,299] Trial 20 finished with value: 0.48418172800247455 and parameters: {'max_depth': 176, 'min_samples_split': 2, 'min_samples_leaf': 11, 'max_features': None}. Best is trial 12 with value: 0.43316182188487423.
# [I 2025-04-14 10:09:30,366] Trial 21 finished with value: 0.4476717046799439 and parameters: {'max_depth': 175, 'min_samples_split': 14, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 12 with value: 0.43316182188487423.
# [I 2025-04-14 10:09:30,425] Trial 22 finished with value: 0.4753075023107572 and parameters: {'max_depth': 183, 'min_samples_split': 17, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 12 with value: 0.43316182188487423.
# [I 2025-04-14 10:09:30,512] Trial 23 finished with value: 0.4476717046799439 and parameters: {'max_depth': 149, 'min_samples_split': 14, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 12 with value: 0.43316182188487423.
# [I 2025-04-14 10:09:30,619] Trial 24 finished with value: 0.4974135337211054 and parameters: {'max_depth': 165, 'min_samples_split': 17, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 12 with value: 0.43316182188487423.
# [I 2025-04-14 10:09:30,714] Trial 25 finished with value: 0.5169416664335623 and parameters: {'max_depth': 103, 'min_samples_split': 13, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 12 with value: 0.43316182188487423.
# [I 2025-04-14 10:09:30,775] Trial 26 finished with value: 0.5856917034964678 and parameters: {'max_depth': 187, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 12 with value: 0.43316182188487423.
# [I 2025-04-14 10:09:30,869] Trial 27 finished with value: 0.45059624836267503 and parameters: {'max_depth': 162, 'min_samples_split': 15, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 12 with value: 0.43316182188487423.
# [I 2025-04-14 10:09:30,970] Trial 28 finished with value: 0.632661116435322 and parameters: {'max_depth': 138, 'min_samples_split': 17, 'min_samples_leaf': 15, 'max_features': 'log2'}. Best is trial 12 with value: 0.43316182188487423.
# [I 2025-04-14 10:09:31,059] Trial 29 finished with value: 0.49532377749423057 and parameters: {'max_depth': 58, 'min_samples_split': 18, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 12 with value: 0.43316182188487423.
# [I 2025-04-14 10:09:31,155] Trial 30 finished with value: 0.48418172800247455 and parameters: {'max_depth': 187, 'min_samples_split': 18, 'min_samples_leaf': 11, 'max_features': None}. Best is trial 12 with value: 0.43316182188487423.
# [I 2025-04-14 10:09:31,261] Trial 31 finished with value: 0.4399500025219837 and parameters: {'max_depth': 170, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_features': None}. Best is trial 12 with value: 0.43316182188487423.
# [I 2025-04-14 10:09:31,377] Trial 32 finished with value: 0.49676121421548336 and parameters: {'max_depth': 166, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_features': None}. Best is trial 12 with value: 0.43316182188487423.
# [I 2025-04-14 10:09:31,474] Trial 33 finished with value: 0.5206028078284158 and parameters: {'max_depth': 154, 'min_samples_split': 13, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 12 with value: 0.43316182188487423.
# [I 2025-04-14 10:09:31,561] Trial 34 finished with value: 0.4629962512675056 and parameters: {'max_depth': 117, 'min_samples_split': 12, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 12 with value: 0.43316182188487423.
# [I 2025-04-14 10:09:31,661] Trial 35 finished with value: 0.4491054909086687 and parameters: {'max_depth': 81, 'min_samples_split': 16, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 12 with value: 0.43316182188487423.
# [I 2025-04-14 10:09:31,759] Trial 36 finished with value: 0.4837977758996909 and parameters: {'max_depth': 183, 'min_samples_split': 14, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 12 with value: 0.43316182188487423.
# [I 2025-04-14 10:09:31,861] Trial 37 finished with value: 0.42588359216258587 and parameters: {'max_depth': 154, 'min_samples_split': 19, 'min_samples_leaf': 12, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:31,930] Trial 38 finished with value: 0.7841835696432616 and parameters: {'max_depth': 142, 'min_samples_split': 19, 'min_samples_leaf': 17, 'max_features': 'sqrt'}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:32,045] Trial 39 finished with value: 0.5853164500741665 and parameters: {'max_depth': 156, 'min_samples_split': 19, 'min_samples_leaf': 13, 'max_features': 'log2'}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:32,149] Trial 40 finished with value: 0.5853164500741665 and parameters: {'max_depth': 168, 'min_samples_split': 17, 'min_samples_leaf': 13, 'max_features': 'sqrt'}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:32,211] Trial 41 finished with value: 0.4753075023107572 and parameters: {'max_depth': 191, 'min_samples_split': 16, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:32,317] Trial 42 finished with value: 0.4487904532810614 and parameters: {'max_depth': 176, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:32,422] Trial 43 finished with value: 0.42588359216258587 and parameters: {'max_depth': 175, 'min_samples_split': 18, 'min_samples_leaf': 12, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:32,519] Trial 44 finished with value: 0.42588359216258587 and parameters: {'max_depth': 198, 'min_samples_split': 20, 'min_samples_leaf': 12, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:32,627] Trial 45 finished with value: 0.42588359216258587 and parameters: {'max_depth': 188, 'min_samples_split': 20, 'min_samples_leaf': 12, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:32,726] Trial 46 finished with value: 0.42588359216258587 and parameters: {'max_depth': 200, 'min_samples_split': 20, 'min_samples_leaf': 12, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:32,823] Trial 47 finished with value: 0.42588359216258587 and parameters: {'max_depth': 200, 'min_samples_split': 20, 'min_samples_leaf': 12, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:32,928] Trial 48 finished with value: 0.5853164500741665 and parameters: {'max_depth': 189, 'min_samples_split': 20, 'min_samples_leaf': 14, 'max_features': 'log2'}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:33,034] Trial 49 finished with value: 0.5830570601450449 and parameters: {'max_depth': 157, 'min_samples_split': 19, 'min_samples_leaf': 12, 'max_features': 'sqrt'}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:33,137] Trial 50 finished with value: 0.7706143352167001 and parameters: {'max_depth': 31, 'min_samples_split': 18, 'min_samples_leaf': 15, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:33,236] Trial 51 finished with value: 0.42588359216258587 and parameters: {'max_depth': 200, 'min_samples_split': 20, 'min_samples_leaf': 12, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:33,355] Trial 52 finished with value: 0.6385207706690795 and parameters: {'max_depth': 194, 'min_samples_split': 20, 'min_samples_leaf': 14, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:33,430] Trial 53 finished with value: 0.48418172800247455 and parameters: {'max_depth': 200, 'min_samples_split': 19, 'min_samples_leaf': 11, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:33,533] Trial 54 finished with value: 0.42588359216258587 and parameters: {'max_depth': 191, 'min_samples_split': 19, 'min_samples_leaf': 12, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:33,627] Trial 55 finished with value: 0.6385207706690795 and parameters: {'max_depth': 181, 'min_samples_split': 20, 'min_samples_leaf': 14, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:33,727] Trial 56 finished with value: 0.44871453655376925 and parameters: {'max_depth': 173, 'min_samples_split': 18, 'min_samples_leaf': 13, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:33,836] Trial 57 finished with value: 0.4753075023107572 and parameters: {'max_depth': 185, 'min_samples_split': 18, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:33,903] Trial 58 finished with value: 0.48418172800247455 and parameters: {'max_depth': 195, 'min_samples_split': 20, 'min_samples_leaf': 11, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:34,006] Trial 59 finished with value: 0.7706143352167001 and parameters: {'max_depth': 200, 'min_samples_split': 20, 'min_samples_leaf': 15, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:34,100] Trial 60 finished with value: 0.42588359216258587 and parameters: {'max_depth': 180, 'min_samples_split': 19, 'min_samples_leaf': 12, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:34,199] Trial 61 finished with value: 0.42588359216258587 and parameters: {'max_depth': 194, 'min_samples_split': 20, 'min_samples_leaf': 12, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:34,308] Trial 62 finished with value: 0.44871453655376925 and parameters: {'max_depth': 188, 'min_samples_split': 20, 'min_samples_leaf': 13, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:34,391] Trial 63 finished with value: 0.42588359216258587 and parameters: {'max_depth': 199, 'min_samples_split': 19, 'min_samples_leaf': 12, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:34,490] Trial 64 finished with value: 0.48418172800247455 and parameters: {'max_depth': 171, 'min_samples_split': 18, 'min_samples_leaf': 11, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:34,591] Trial 65 finished with value: 0.4753075023107572 and parameters: {'max_depth': 192, 'min_samples_split': 19, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:34,705] Trial 66 finished with value: 0.7080449601497 and parameters: {'max_depth': 179, 'min_samples_split': 17, 'min_samples_leaf': 20, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:34,813] Trial 67 finished with value: 0.47535209211059976 and parameters: {'max_depth': 161, 'min_samples_split': 20, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:34,922] Trial 68 finished with value: 0.5853164500741665 and parameters: {'max_depth': 184, 'min_samples_split': 18, 'min_samples_leaf': 13, 'max_features': 'log2'}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:35,033] Trial 69 finished with value: 0.6385207706690795 and parameters: {'max_depth': 131, 'min_samples_split': 20, 'min_samples_leaf': 14, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:35,146] Trial 70 finished with value: 0.42588359216258587 and parameters: {'max_depth': 200, 'min_samples_split': 19, 'min_samples_leaf': 12, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:35,252] Trial 71 finished with value: 0.42588359216258587 and parameters: {'max_depth': 190, 'min_samples_split': 19, 'min_samples_leaf': 12, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:35,364] Trial 72 finished with value: 0.48418172800247455 and parameters: {'max_depth': 192, 'min_samples_split': 19, 'min_samples_leaf': 11, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:35,475] Trial 73 finished with value: 0.42588359216258587 and parameters: {'max_depth': 172, 'min_samples_split': 18, 'min_samples_leaf': 12, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:35,550] Trial 74 finished with value: 0.7506453431140764 and parameters: {'max_depth': 186, 'min_samples_split': 6, 'min_samples_leaf': 16, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:35,658] Trial 75 finished with value: 0.5333695245249244 and parameters: {'max_depth': 195, 'min_samples_split': 17, 'min_samples_leaf': 10, 'max_features': 'sqrt'}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:35,766] Trial 76 finished with value: 0.44871453655376925 and parameters: {'max_depth': 112, 'min_samples_split': 20, 'min_samples_leaf': 13, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:35,866] Trial 77 finished with value: 0.48418172800247455 and parameters: {'max_depth': 147, 'min_samples_split': 19, 'min_samples_leaf': 11, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:35,960] Trial 78 finished with value: 0.42588359216258587 and parameters: {'max_depth': 75, 'min_samples_split': 3, 'min_samples_leaf': 12, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:36,076] Trial 79 finished with value: 0.6385207706690795 and parameters: {'max_depth': 176, 'min_samples_split': 10, 'min_samples_leaf': 14, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:36,175] Trial 80 finished with value: 0.5853164500741665 and parameters: {'max_depth': 167, 'min_samples_split': 20, 'min_samples_leaf': 13, 'max_features': 'log2'}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:36,297] Trial 81 finished with value: 0.48418172800247455 and parameters: {'max_depth': 181, 'min_samples_split': 19, 'min_samples_leaf': 11, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:36,401] Trial 82 finished with value: 0.42588359216258587 and parameters: {'max_depth': 179, 'min_samples_split': 18, 'min_samples_leaf': 12, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:36,505] Trial 83 finished with value: 0.44871453655376925 and parameters: {'max_depth': 189, 'min_samples_split': 19, 'min_samples_leaf': 13, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:36,558] Trial 84 finished with value: 0.42588359216258587 and parameters: {'max_depth': 160, 'min_samples_split': 17, 'min_samples_leaf': 12, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:36,683] Trial 85 finished with value: 0.47535209211059976 and parameters: {'max_depth': 196, 'min_samples_split': 20, 'min_samples_leaf': 9, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:36,797] Trial 86 finished with value: 0.4753075023107572 and parameters: {'max_depth': 183, 'min_samples_split': 18, 'min_samples_leaf': 10, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:36,860] Trial 87 finished with value: 0.48418172800247455 and parameters: {'max_depth': 177, 'min_samples_split': 19, 'min_samples_leaf': 11, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:36,972] Trial 88 finished with value: 0.632661116435322 and parameters: {'max_depth': 188, 'min_samples_split': 20, 'min_samples_leaf': 15, 'max_features': 'sqrt'}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:37,081] Trial 89 finished with value: 0.6385207706690795 and parameters: {'max_depth': 151, 'min_samples_split': 19, 'min_samples_leaf': 14, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:37,183] Trial 90 finished with value: 0.44871453655376925 and parameters: {'max_depth': 197, 'min_samples_split': 20, 'min_samples_leaf': 13, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:37,278] Trial 91 finished with value: 0.42588359216258587 and parameters: {'max_depth': 194, 'min_samples_split': 20, 'min_samples_leaf': 12, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:37,406] Trial 92 finished with value: 0.42588359216258587 and parameters: {'max_depth': 192, 'min_samples_split': 20, 'min_samples_leaf': 12, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:37,511] Trial 93 finished with value: 0.48418172800247455 and parameters: {'max_depth': 200, 'min_samples_split': 19, 'min_samples_leaf': 11, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:37,633] Trial 94 finished with value: 0.44871453655376925 and parameters: {'max_depth': 184, 'min_samples_split': 18, 'min_samples_leaf': 13, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:37,739] Trial 95 finished with value: 0.42588359216258587 and parameters: {'max_depth': 172, 'min_samples_split': 20, 'min_samples_leaf': 12, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:37,852] Trial 96 finished with value: 0.48418172800247455 and parameters: {'max_depth': 195, 'min_samples_split': 19, 'min_samples_leaf': 11, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:37,930] Trial 97 finished with value: 0.44871453655376925 and parameters: {'max_depth': 187, 'min_samples_split': 17, 'min_samples_leaf': 13, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:38,034] Trial 98 finished with value: 0.5333695245249244 and parameters: {'max_depth': 164, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 37 with value: 0.42588359216258587.
# [I 2025-04-14 10:09:38,154] Trial 99 finished with value: 0.42588359216258587 and parameters: {'max_depth': 181, 'min_samples_split': 18, 'min_samples_leaf': 12, 'max_features': None}. Best is trial 37 with value: 0.42588359216258587.
# Best parameters found by Optuna: {'max_depth': 154, 'min_samples_split': 19, 'min_samples_leaf': 12, 'max_features': None}
#
# Top 10 Hyperparameter Combinations and Scores:
# Rank 1: Trial 37
# Parameters: {'max_depth': 154, 'min_samples_split': 19, 'min_samples_leaf': 12, 'max_features': None}
# Training Set - R²: 0.651, RMSE: 0.258, mean_ratio: 1.169, cov_ratio(%): 53.5
# Testing Set  - R²: 0.617, RMSE: 0.287, mean_ratio: 1.264, cov_ratio(%): 45.9
#
# Rank 2: Trial 43
# Parameters: {'max_depth': 175, 'min_samples_split': 18, 'min_samples_leaf': 12, 'max_features': None}
# Training Set - R²: 0.651, RMSE: 0.258, mean_ratio: 1.169, cov_ratio(%): 53.5
# Testing Set  - R²: 0.617, RMSE: 0.287, mean_ratio: 1.264, cov_ratio(%): 45.9
#
# Rank 3: Trial 44
# Parameters: {'max_depth': 198, 'min_samples_split': 20, 'min_samples_leaf': 12, 'max_features': None}
# Training Set - R²: 0.651, RMSE: 0.258, mean_ratio: 1.169, cov_ratio(%): 53.5
# Testing Set  - R²: 0.617, RMSE: 0.287, mean_ratio: 1.264, cov_ratio(%): 45.9
#
# Rank 4: Trial 45
# Parameters: {'max_depth': 188, 'min_samples_split': 20, 'min_samples_leaf': 12, 'max_features': None}
# Training Set - R²: 0.651, RMSE: 0.258, mean_ratio: 1.169, cov_ratio(%): 53.5
# Testing Set  - R²: 0.617, RMSE: 0.287, mean_ratio: 1.264, cov_ratio(%): 45.9
#
# Rank 5: Trial 46
# Parameters: {'max_depth': 200, 'min_samples_split': 20, 'min_samples_leaf': 12, 'max_features': None}
# Training Set - R²: 0.651, RMSE: 0.258, mean_ratio: 1.169, cov_ratio(%): 53.5
# Testing Set  - R²: 0.617, RMSE: 0.287, mean_ratio: 1.264, cov_ratio(%): 45.9
#
# Rank 6: Trial 47
# Parameters: {'max_depth': 200, 'min_samples_split': 20, 'min_samples_leaf': 12, 'max_features': None}
# Training Set - R²: 0.651, RMSE: 0.258, mean_ratio: 1.169, cov_ratio(%): 53.5
# Testing Set  - R²: 0.617, RMSE: 0.287, mean_ratio: 1.264, cov_ratio(%): 45.9
#
# Rank 7: Trial 51
# Parameters: {'max_depth': 200, 'min_samples_split': 20, 'min_samples_leaf': 12, 'max_features': None}
# Training Set - R²: 0.651, RMSE: 0.258, mean_ratio: 1.169, cov_ratio(%): 53.5
# Testing Set  - R²: 0.617, RMSE: 0.287, mean_ratio: 1.264, cov_ratio(%): 45.9
#
# Rank 8: Trial 54
# Parameters: {'max_depth': 191, 'min_samples_split': 19, 'min_samples_leaf': 12, 'max_features': None}
# Training Set - R²: 0.651, RMSE: 0.258, mean_ratio: 1.169, cov_ratio(%): 53.5
# Testing Set  - R²: 0.617, RMSE: 0.287, mean_ratio: 1.264, cov_ratio(%): 45.9
#
# Rank 9: Trial 60
# Parameters: {'max_depth': 180, 'min_samples_split': 19, 'min_samples_leaf': 12, 'max_features': None}
# Training Set - R²: 0.651, RMSE: 0.258, mean_ratio: 1.169, cov_ratio(%): 53.5
# Testing Set  - R²: 0.617, RMSE: 0.287, mean_ratio: 1.264, cov_ratio(%): 45.9
#
# Rank 10: Trial 61
# Parameters: {'max_depth': 194, 'min_samples_split': 20, 'min_samples_leaf': 12, 'max_features': None}
# Training Set - R²: 0.651, RMSE: 0.258, mean_ratio: 1.169, cov_ratio(%): 53.5
# Testing Set  - R²: 0.617, RMSE: 0.287, mean_ratio: 1.264, cov_ratio(%): 45.9
