# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, root_mean_squared_error
from sklearn.neural_network import MLPRegressor
import optuna
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

num_trials = 100;

# Load data
shear_strength = pd.read_csv('shear_strength.csv', header=None)
new_or_old = pd.read_csv('new_or_old.csv', header=None)
load_type = pd.read_csv('load_type.csv', header=None)
wall_l = pd.read_csv('wall_l.csv', header=None)
wall_h = pd.read_csv('wall_h.csv', header=None)
wall_t = pd.read_csv('wall_t.csv', header=None)
leaf_num = pd.read_csv('leaf_num.csv', header=None)
bond_pattern = pd.read_csv('bond_pattern.csv', header=None)
ft_mortar = pd.read_csv('ft_mortar.csv', header=None)
ft_brick = pd.read_csv('ft_brick.csv', header=None)

# Combine features and target
X = pd.concat([new_or_old, wall_l, wall_t, leaf_num, bond_pattern, ft_mortar, ft_brick], axis=1)
X.columns = ['new_or_old', 'wall_l', 'wall_t', 'leaf_num', 'bond_pattern', 'ft_mortar', 'ft_brick']
y_raw = shear_strength 
y_raw.columns = ['shear_strength']
y = np.log(y_raw)  # log-transform (natural log)
y.columns = ['shear_strength']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=4)

# Scale data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

trial_results = []

# Optuna objective function
def objective(trial):
    n_layers = trial.suggest_int("n_layers", 1, 4) 
    hidden_layer_sizes = tuple(
        [trial.suggest_int(f"n_units_{i}", 100, 1000) for i in range(n_layers)] 
    )
    activation = trial.suggest_categorical("activation", ["relu", "tanh", "logistic"])

    model = MLPRegressor(
        hidden_layer_sizes=hidden_layer_sizes,
        activation=activation,
        max_iter=1000,
        random_state=0
    )

    cv = KFold(n_splits=10, shuffle=True, random_state=0)
    scores = cross_val_score(model, X_train, y_train.values.ravel(), cv=cv, scoring="neg_mean_squared_error")
    return -scores.mean()

# Run Optuna optimization
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=num_trials)

# Best parameters
print("Best parameters found by Optuna:", study.best_params)

trial_results = sorted(
    [(t.number, t.value, t.params) for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE],
    key=lambda x: x[1]
)[:10]

print("\nTop 10 Hyperparameter Combinations and Scores:")
for rank, (trial_number, mse, params) in enumerate(trial_results, start=1):
    model = MLPRegressor(
        hidden_layer_sizes=tuple([params[f"n_units_{i}"] for i in range(params["n_layers"])]),
        activation=params["activation"],
        max_iter=1000,
        random_state=0
    )
    
    model.fit(X_train, y_train.values.ravel())

    y_train_pred_log = model.predict(X_train)
    y_test_pred_log = model.predict(X_test)

    y_train_pred = np.exp(y_train_pred_log)
    y_test_pred = np.exp(y_test_pred_log)

    y_train_np = y_raw.iloc[y_train.index].to_numpy().squeeze()
    y_test_np = y_raw.iloc[y_test.index].to_numpy().squeeze()
    
    # Calculate metrics for training set
    r2_train = r2_score(y_train_np, y_train_pred)
    rmse_train = root_mean_squared_error(y_train_np, y_train_pred)
    ratio_train = y_train_np / y_train_pred
    mean_ratio_train = np.mean(ratio_train)
    cov_ratio_p_train = np.cov(ratio_train, rowvar=False, ddof=1)
    cov_ratio_p_train = cov_ratio_p_train * 100
    
    # Calculate metrics for testing set
    r2_test = r2_score(y_test_np, y_test_pred)
    rmse_test = root_mean_squared_error(y_test_np, y_test_pred)
    ratio_test = y_test_np / y_test_pred
    mean_ratio_test = np.mean(ratio_test)
    cov_ratio_p_test = np.cov(ratio_test, rowvar=False, ddof=1)
    cov_ratio_p_test = cov_ratio_p_test * 100
    
    # Print results
    print(f"Rank {rank}: Trial {trial_number}")
    print(f"Parameters: {params}")
    print(f"Training Set - R²: {r2_train:.3f}, RMSE: {rmse_train:.3f}, mean_ratio: {mean_ratio_train:.3f}, cov_ratio(%): {cov_ratio_p_train:.1f}")
    print(f"Testing Set  - R²: {r2_test:.3f}, RMSE: {rmse_test:.3f}, mean_ratio: {mean_ratio_test:.3f}, cov_ratio(%): {cov_ratio_p_test:.1f}\n")
# Out:
# [I 2025-04-14 10:27:50,903] A new study created in memory with name: no-name-098ded02-87b4-495c-ac38-bfbf0e752aed
# [I 2025-04-14 10:33:42,035] Trial 0 finished with value: 0.7745851707288475 and parameters: {'n_layers': 3, 'n_units_0': 235, 'n_units_1': 964, 'n_units_2': 932, 'activation': 'tanh'}. Best is trial 0 with value: 0.7745851707288475.
# [I 2025-04-14 10:37:15,783] Trial 1 finished with value: 1.7046949399032318 and parameters: {'n_layers': 3, 'n_units_0': 271, 'n_units_1': 845, 'n_units_2': 527, 'activation': 'tanh'}. Best is trial 0 with value: 0.7745851707288475.
# [I 2025-04-14 10:39:14,112] Trial 2 finished with value: 0.5783377026404096 and parameters: {'n_layers': 2, 'n_units_0': 774, 'n_units_1': 915, 'activation': 'relu'}. Best is trial 2 with value: 0.5783377026404096.
# [I 2025-04-14 10:40:39,369] Trial 3 finished with value: 0.5106866972037014 and parameters: {'n_layers': 2, 'n_units_0': 555, 'n_units_1': 953, 'activation': 'relu'}. Best is trial 3 with value: 0.5106866972037014.
# [I 2025-04-14 10:43:50,847] Trial 4 finished with value: 1.6932359085043214 and parameters: {'n_layers': 2, 'n_units_0': 349, 'n_units_1': 893, 'activation': 'tanh'}. Best is trial 3 with value: 0.5106866972037014.
# [I 2025-04-14 10:44:12,980] Trial 5 finished with value: 0.8004662509424831 and parameters: {'n_layers': 1, 'n_units_0': 676, 'activation': 'logistic'}. Best is trial 3 with value: 0.5106866972037014.
# [I 2025-04-14 10:51:02,701] Trial 6 finished with value: 1.856184653851594 and parameters: {'n_layers': 2, 'n_units_0': 965, 'n_units_1': 957, 'activation': 'tanh'}. Best is trial 3 with value: 0.5106866972037014.
# [I 2025-04-14 10:51:49,863] Trial 7 finished with value: 1.6957552013715436 and parameters: {'n_layers': 2, 'n_units_0': 572, 'n_units_1': 152, 'activation': 'tanh'}. Best is trial 3 with value: 0.5106866972037014.
# [I 2025-04-14 10:53:12,208] Trial 8 finished with value: 0.5205675806052465 and parameters: {'n_layers': 2, 'n_units_0': 483, 'n_units_1': 978, 'activation': 'relu'}. Best is trial 3 with value: 0.5106866972037014.
# [I 2025-04-14 10:53:33,043] Trial 9 finished with value: 0.7944834689149418 and parameters: {'n_layers': 1, 'n_units_0': 641, 'activation': 'logistic'}. Best is trial 3 with value: 0.5106866972037014.
# [I 2025-04-14 10:54:57,875] Trial 10 finished with value: 0.4985546847611227 and parameters: {'n_layers': 4, 'n_units_0': 878, 'n_units_1': 616, 'n_units_2': 151, 'n_units_3': 890, 'activation': 'relu'}. Best is trial 10 with value: 0.4985546847611227.
# [I 2025-04-14 10:56:19,927] Trial 11 finished with value: 0.5986880318886587 and parameters: {'n_layers': 4, 'n_units_0': 995, 'n_units_1': 499, 'n_units_2': 119, 'n_units_3': 963, 'activation': 'relu'}. Best is trial 10 with value: 0.4985546847611227.
# [I 2025-04-14 10:56:51,860] Trial 12 finished with value: 0.4016948085721451 and parameters: {'n_layers': 4, 'n_units_0': 108, 'n_units_1': 628, 'n_units_2': 146, 'n_units_3': 716, 'activation': 'relu'}. Best is trial 12 with value: 0.4016948085721451.
# [I 2025-04-14 10:57:22,442] Trial 13 finished with value: 0.4514157304425897 and parameters: {'n_layers': 4, 'n_units_0': 118, 'n_units_1': 618, 'n_units_2': 106, 'n_units_3': 746, 'activation': 'relu'}. Best is trial 12 with value: 0.4016948085721451.
# [I 2025-04-14 10:58:19,742] Trial 14 finished with value: 0.3479164303420042 and parameters: {'n_layers': 4, 'n_units_0': 110, 'n_units_1': 641, 'n_units_2': 349, 'n_units_3': 519, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 10:58:56,797] Trial 15 finished with value: 0.39075954472237867 and parameters: {'n_layers': 3, 'n_units_0': 110, 'n_units_1': 436, 'n_units_2': 406, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 10:59:52,196] Trial 16 finished with value: 0.519719119487951 and parameters: {'n_layers': 3, 'n_units_0': 400, 'n_units_1': 450, 'n_units_2': 440, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:01:19,909] Trial 17 finished with value: 0.7564149693713407 and parameters: {'n_layers': 3, 'n_units_0': 199, 'n_units_1': 340, 'n_units_2': 374, 'activation': 'logistic'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:03:04,263] Trial 18 finished with value: 0.5585621773768705 and parameters: {'n_layers': 4, 'n_units_0': 334, 'n_units_1': 744, 'n_units_2': 741, 'n_units_3': 259, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:03:31,917] Trial 19 finished with value: 0.43371024214194137 and parameters: {'n_layers': 3, 'n_units_0': 183, 'n_units_1': 342, 'n_units_2': 339, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:04:03,489] Trial 20 finished with value: 0.9003503899690809 and parameters: {'n_layers': 4, 'n_units_0': 290, 'n_units_1': 406, 'n_units_2': 684, 'n_units_3': 386, 'activation': 'logistic'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:04:56,795] Trial 21 finished with value: 0.5439112346674535 and parameters: {'n_layers': 4, 'n_units_0': 107, 'n_units_1': 740, 'n_units_2': 272, 'n_units_3': 599, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:05:48,925] Trial 22 finished with value: 0.4821392821288725 and parameters: {'n_layers': 4, 'n_units_0': 104, 'n_units_1': 597, 'n_units_2': 258, 'n_units_3': 538, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:07:04,606] Trial 23 finished with value: 0.552070586087947 and parameters: {'n_layers': 3, 'n_units_0': 442, 'n_units_1': 722, 'n_units_2': 483, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:07:57,386] Trial 24 finished with value: 0.49760143407051 and parameters: {'n_layers': 4, 'n_units_0': 177, 'n_units_1': 534, 'n_units_2': 255, 'n_units_3': 620, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:08:35,477] Trial 25 finished with value: 0.5656892814782777 and parameters: {'n_layers': 3, 'n_units_0': 171, 'n_units_1': 246, 'n_units_2': 616, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:09:41,224] Trial 26 finished with value: 0.49205812408468086 and parameters: {'n_layers': 4, 'n_units_0': 267, 'n_units_1': 679, 'n_units_2': 388, 'n_units_3': 378, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:10:49,264] Trial 27 finished with value: 0.4671138619749134 and parameters: {'n_layers': 3, 'n_units_0': 359, 'n_units_1': 790, 'n_units_2': 216, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:11:19,937] Trial 28 finished with value: 1.0119136572471503 and parameters: {'n_layers': 4, 'n_units_0': 220, 'n_units_1': 474, 'n_units_2': 319, 'n_units_3': 816, 'activation': 'logistic'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:12:17,472] Trial 29 finished with value: 0.4365376545362861 and parameters: {'n_layers': 3, 'n_units_0': 153, 'n_units_1': 553, 'n_units_2': 596, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:15:14,949] Trial 30 finished with value: 1.5831282364696553 and parameters: {'n_layers': 4, 'n_units_0': 239, 'n_units_1': 664, 'n_units_2': 436, 'n_units_3': 703, 'activation': 'tanh'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:15:40,032] Trial 31 finished with value: 0.4922495835614488 and parameters: {'n_layers': 3, 'n_units_0': 163, 'n_units_1': 328, 'n_units_2': 357, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:16:07,832] Trial 32 finished with value: 0.5559194498172223 and parameters: {'n_layers': 3, 'n_units_0': 290, 'n_units_1': 385, 'n_units_2': 186, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:16:30,665] Trial 33 finished with value: 0.48856823225701024 and parameters: {'n_layers': 3, 'n_units_0': 218, 'n_units_1': 243, 'n_units_2': 325, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:16:56,224] Trial 34 finished with value: 0.46926430122921337 and parameters: {'n_layers': 3, 'n_units_0': 148, 'n_units_1': 270, 'n_units_2': 452, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:17:56,913] Trial 35 finished with value: 0.5103923386141489 and parameters: {'n_layers': 4, 'n_units_0': 224, 'n_units_1': 556, 'n_units_2': 292, 'n_units_3': 475, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:18:57,536] Trial 36 finished with value: 1.4292506748849907 and parameters: {'n_layers': 2, 'n_units_0': 115, 'n_units_1': 407, 'activation': 'tanh'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:20:19,035] Trial 37 finished with value: 0.4212598195665039 and parameters: {'n_layers': 3, 'n_units_0': 315, 'n_units_1': 830, 'n_units_2': 526, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:21:18,257] Trial 38 finished with value: 0.48536050851298285 and parameters: {'n_layers': 2, 'n_units_0': 298, 'n_units_1': 861, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:23:44,701] Trial 39 finished with value: 1.0297359484529383 and parameters: {'n_layers': 4, 'n_units_0': 465, 'n_units_1': 807, 'n_units_2': 553, 'n_units_3': 143, 'activation': 'tanh'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:24:03,597] Trial 40 finished with value: 0.7979290350599432 and parameters: {'n_layers': 1, 'n_units_0': 528, 'activation': 'logistic'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:24:59,587] Trial 41 finished with value: 0.4707260419578443 and parameters: {'n_layers': 3, 'n_units_0': 181, 'n_units_1': 672, 'n_units_2': 504, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:25:44,034] Trial 42 finished with value: 0.35568063678871936 and parameters: {'n_layers': 3, 'n_units_0': 243, 'n_units_1': 166, 'n_units_2': 988, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:26:08,685] Trial 43 finished with value: 0.4559551243871468 and parameters: {'n_layers': 3, 'n_units_0': 385, 'n_units_1': 124, 'n_units_2': 824, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:27:03,455] Trial 44 finished with value: 0.5887663283946291 and parameters: {'n_layers': 2, 'n_units_0': 262, 'n_units_1': 803, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:29:37,560] Trial 45 finished with value: 0.5082488760496341 and parameters: {'n_layers': 3, 'n_units_0': 700, 'n_units_1': 911, 'n_units_2': 967, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:29:54,328] Trial 46 finished with value: 0.5127631983982875 and parameters: {'n_layers': 2, 'n_units_0': 132, 'n_units_1': 195, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:34:09,926] Trial 47 finished with value: 1.720576788347266 and parameters: {'n_layers': 3, 'n_units_0': 325, 'n_units_1': 632, 'n_units_2': 864, 'activation': 'tanh'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:35:34,429] Trial 48 finished with value: 0.5258986665278033 and parameters: {'n_layers': 4, 'n_units_0': 101, 'n_units_1': 512, 'n_units_2': 649, 'n_units_3': 711, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:36:17,411] Trial 49 finished with value: 0.5580701940617941 and parameters: {'n_layers': 3, 'n_units_0': 846, 'n_units_1': 188, 'n_units_2': 558, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:41:51,165] Trial 50 finished with value: 0.6840528296595753 and parameters: {'n_layers': 4, 'n_units_0': 231, 'n_units_1': 581, 'n_units_2': 407, 'n_units_3': 370, 'activation': 'logistic'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:42:13,788] Trial 51 finished with value: 0.49825912474242495 and parameters: {'n_layers': 3, 'n_units_0': 203, 'n_units_1': 322, 'n_units_2': 165, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:43:00,711] Trial 52 finished with value: 0.4622549377512201 and parameters: {'n_layers': 3, 'n_units_0': 152, 'n_units_1': 462, 'n_units_2': 490, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:43:23,473] Trial 53 finished with value: 0.45625115312347353 and parameters: {'n_layers': 3, 'n_units_0': 187, 'n_units_1': 371, 'n_units_2': 219, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:43:48,048] Trial 54 finished with value: 0.5857935818028137 and parameters: {'n_layers': 2, 'n_units_0': 138, 'n_units_1': 291, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:44:27,509] Trial 55 finished with value: 0.4893901989539956 and parameters: {'n_layers': 3, 'n_units_0': 246, 'n_units_1': 448, 'n_units_2': 358, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:45:11,244] Trial 56 finished with value: 0.4888850745415029 and parameters: {'n_layers': 4, 'n_units_0': 306, 'n_units_1': 114, 'n_units_2': 426, 'n_units_3': 473, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:46:54,584] Trial 57 finished with value: 0.4770496313506839 and parameters: {'n_layers': 3, 'n_units_0': 403, 'n_units_1': 863, 'n_units_2': 729, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:48:14,731] Trial 58 finished with value: 0.42956332114474627 and parameters: {'n_layers': 4, 'n_units_0': 199, 'n_units_1': 717, 'n_units_2': 318, 'n_units_3': 831, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:49:29,123] Trial 59 finished with value: 0.5462262504154201 and parameters: {'n_layers': 4, 'n_units_0': 599, 'n_units_1': 773, 'n_units_2': 102, 'n_units_3': 819, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:53:48,303] Trial 60 finished with value: 0.7732811154662708 and parameters: {'n_layers': 4, 'n_units_0': 364, 'n_units_1': 704, 'n_units_2': 470, 'n_units_3': 977, 'activation': 'logistic'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:54:47,020] Trial 61 finished with value: 0.4601921552979607 and parameters: {'n_layers': 4, 'n_units_0': 187, 'n_units_1': 638, 'n_units_2': 324, 'n_units_3': 645, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:55:57,480] Trial 62 finished with value: 0.4884574272402147 and parameters: {'n_layers': 4, 'n_units_0': 124, 'n_units_1': 757, 'n_units_2': 384, 'n_units_3': 797, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:56:58,611] Trial 63 finished with value: 0.5833013156197501 and parameters: {'n_layers': 4, 'n_units_0': 266, 'n_units_1': 709, 'n_units_2': 226, 'n_units_3': 891, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:58:09,100] Trial 64 finished with value: 0.4272025669305403 and parameters: {'n_layers': 3, 'n_units_0': 205, 'n_units_1': 985, 'n_units_2': 338, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 11:59:16,711] Trial 65 finished with value: 0.4112014002937149 and parameters: {'n_layers': 4, 'n_units_0': 201, 'n_units_1': 828, 'n_units_2': 292, 'n_units_3': 540, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:00:19,909] Trial 66 finished with value: 0.46224909294000505 and parameters: {'n_layers': 3, 'n_units_0': 155, 'n_units_1': 951, 'n_units_2': 280, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:00:28,949] Trial 67 finished with value: 0.6716904009501822 and parameters: {'n_layers': 1, 'n_units_0': 102, 'activation': 'tanh'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:02:17,834] Trial 68 finished with value: 0.5092238056306357 and parameters: {'n_layers': 4, 'n_units_0': 327, 'n_units_1': 945, 'n_units_2': 521, 'n_units_3': 529, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:03:22,859] Trial 69 finished with value: 0.488951609903627 and parameters: {'n_layers': 3, 'n_units_0': 246, 'n_units_1': 823, 'n_units_2': 404, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:04:05,375] Trial 70 finished with value: 0.49113467242090403 and parameters: {'n_layers': 3, 'n_units_0': 213, 'n_units_1': 888, 'n_units_2': 133, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:05:03,860] Trial 71 finished with value: 0.5757032422503296 and parameters: {'n_layers': 4, 'n_units_0': 132, 'n_units_1': 596, 'n_units_2': 297, 'n_units_3': 638, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:06:05,375] Trial 72 finished with value: 0.5673054196962604 and parameters: {'n_layers': 4, 'n_units_0': 200, 'n_units_1': 976, 'n_units_2': 245, 'n_units_3': 493, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:07:23,395] Trial 73 finished with value: 0.5450232574738199 and parameters: {'n_layers': 4, 'n_units_0': 157, 'n_units_1': 838, 'n_units_2': 358, 'n_units_3': 692, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:08:26,593] Trial 74 finished with value: 0.5125043507153563 and parameters: {'n_layers': 4, 'n_units_0': 281, 'n_units_1': 732, 'n_units_2': 301, 'n_units_3': 422, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:09:35,392] Trial 75 finished with value: 0.5123089989694287 and parameters: {'n_layers': 4, 'n_units_0': 176, 'n_units_1': 992, 'n_units_2': 165, 'n_units_3': 900, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:10:23,411] Trial 76 finished with value: 0.4851793158468592 and parameters: {'n_layers': 4, 'n_units_0': 251, 'n_units_1': 648, 'n_units_2': 198, 'n_units_3': 569, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:13:23,641] Trial 77 finished with value: 0.6878170586556847 and parameters: {'n_layers': 3, 'n_units_0': 214, 'n_units_1': 694, 'n_units_2': 343, 'activation': 'logistic'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:14:26,306] Trial 78 finished with value: 0.5256968385185713 and parameters: {'n_layers': 4, 'n_units_0': 134, 'n_units_1': 880, 'n_units_2': 254, 'n_units_3': 766, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:15:43,698] Trial 79 finished with value: 1.0611876639990006 and parameters: {'n_layers': 2, 'n_units_0': 100, 'n_units_1': 921, 'activation': 'tanh'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:16:41,838] Trial 80 finished with value: 0.5200236711961395 and parameters: {'n_layers': 3, 'n_units_0': 164, 'n_units_1': 769, 'n_units_2': 446, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:17:22,766] Trial 81 finished with value: 0.4590846301816055 and parameters: {'n_layers': 3, 'n_units_0': 195, 'n_units_1': 508, 'n_units_2': 326, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:18:13,958] Trial 82 finished with value: 0.5657894772115325 and parameters: {'n_layers': 3, 'n_units_0': 125, 'n_units_1': 560, 'n_units_2': 403, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:19:00,724] Trial 83 finished with value: 0.4433601907604511 and parameters: {'n_layers': 3, 'n_units_0': 227, 'n_units_1': 610, 'n_units_2': 276, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:19:26,728] Trial 84 finished with value: 0.487645540013526 and parameters: {'n_layers': 3, 'n_units_0': 178, 'n_units_1': 200, 'n_units_2': 365, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:20:51,827] Trial 85 finished with value: 0.5233379267189521 and parameters: {'n_layers': 4, 'n_units_0': 274, 'n_units_1': 425, 'n_units_2': 608, 'n_units_3': 853, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:22:21,890] Trial 86 finished with value: 0.4671953563029483 and parameters: {'n_layers': 3, 'n_units_0': 307, 'n_units_1': 666, 'n_units_2': 865, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:23:20,250] Trial 87 finished with value: 0.4233826681467182 and parameters: {'n_layers': 4, 'n_units_0': 147, 'n_units_1': 363, 'n_units_2': 335, 'n_units_3': 946, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:24:53,406] Trial 88 finished with value: 0.39314846683766924 and parameters: {'n_layers': 4, 'n_units_0': 141, 'n_units_1': 578, 'n_units_2': 568, 'n_units_3': 938, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:27:17,598] Trial 89 finished with value: 0.48390959078228646 and parameters: {'n_layers': 4, 'n_units_0': 140, 'n_units_1': 522, 'n_units_2': 992, 'n_units_3': 930, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:29:07,774] Trial 90 finished with value: 0.5364132110321072 and parameters: {'n_layers': 4, 'n_units_0': 159, 'n_units_1': 568, 'n_units_2': 676, 'n_units_3': 982, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:30:17,835] Trial 91 finished with value: 0.6045016974996444 and parameters: {'n_layers': 4, 'n_units_0': 120, 'n_units_1': 626, 'n_units_2': 310, 'n_units_3': 930, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:31:54,362] Trial 92 finished with value: 0.4590123340319835 and parameters: {'n_layers': 4, 'n_units_0': 202, 'n_units_1': 588, 'n_units_2': 579, 'n_units_3': 876, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:33:19,719] Trial 93 finished with value: 0.4903421573850489 and parameters: {'n_layers': 4, 'n_units_0': 517, 'n_units_1': 484, 'n_units_2': 426, 'n_units_3': 757, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:35:03,795] Trial 94 finished with value: 0.498998053799298 and parameters: {'n_layers': 4, 'n_units_0': 168, 'n_units_1': 361, 'n_units_2': 777, 'n_units_3': 933, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:40:36,030] Trial 95 finished with value: 1.0941813477361173 and parameters: {'n_layers': 4, 'n_units_0': 235, 'n_units_1': 652, 'n_units_2': 464, 'n_units_3': 858, 'activation': 'logistic'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:41:39,565] Trial 96 finished with value: 0.48661788981125553 and parameters: {'n_layers': 4, 'n_units_0': 145, 'n_units_1': 534, 'n_units_2': 380, 'n_units_3': 597, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:43:21,105] Trial 97 finished with value: 0.961727223367015 and parameters: {'n_layers': 4, 'n_units_0': 113, 'n_units_1': 691, 'n_units_2': 339, 'n_units_3': 309, 'activation': 'tanh'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:45:06,895] Trial 98 finished with value: 0.5324717508505857 and parameters: {'n_layers': 4, 'n_units_0': 708, 'n_units_1': 290, 'n_units_2': 639, 'n_units_3': 996, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# [I 2025-04-14 12:46:31,261] Trial 99 finished with value: 0.46584290463639705 and parameters: {'n_layers': 4, 'n_units_0': 183, 'n_units_1': 615, 'n_units_2': 528, 'n_units_3': 831, 'activation': 'relu'}. Best is trial 14 with value: 0.3479164303420042.
# Best parameters found by Optuna: {'n_layers': 4, 'n_units_0': 110, 'n_units_1': 641, 'n_units_2': 349, 'n_units_3': 519, 'activation': 'relu'}
#
# Top 10 Hyperparameter Combinations and Scores:
# Rank 1: Trial 14
# Parameters: {'n_layers': 4, 'n_units_0': 110, 'n_units_1': 641, 'n_units_2': 349, 'n_units_3': 519, 'activation': 'relu'}
# Training Set - R²: 0.949, RMSE: 0.098, mean_ratio: 1.009, cov_ratio(%): 1.6
# Testing Set  - R²: 0.848, RMSE: 0.181, mean_ratio: 1.092, cov_ratio(%): 25.7
#
# Rank 2: Trial 42
# Parameters: {'n_layers': 3, 'n_units_0': 243, 'n_units_1': 166, 'n_units_2': 988, 'activation': 'relu'}
# Training Set - R²: 0.949, RMSE: 0.099, mean_ratio: 1.010, cov_ratio(%): 1.8
# Testing Set  - R²: 0.772, RMSE: 0.221, mean_ratio: 1.032, cov_ratio(%): 24.0
#
# Rank 3: Trial 15
# Parameters: {'n_layers': 3, 'n_units_0': 110, 'n_units_1': 436, 'n_units_2': 406, 'activation': 'relu'}
# Training Set - R²: 0.949, RMSE: 0.099, mean_ratio: 1.008, cov_ratio(%): 1.7
# Testing Set  - R²: 0.869, RMSE: 0.168, mean_ratio: 1.116, cov_ratio(%): 22.1
#
# Rank 4: Trial 88
# Parameters: {'n_layers': 4, 'n_units_0': 141, 'n_units_1': 578, 'n_units_2': 568, 'n_units_3': 938, 'activation': 'relu'}
# Training Set - R²: 0.950, RMSE: 0.098, mean_ratio: 1.004, cov_ratio(%): 1.5
# Testing Set  - R²: 0.860, RMSE: 0.174, mean_ratio: 1.097, cov_ratio(%): 29.3
#
# Rank 5: Trial 12
# Parameters: {'n_layers': 4, 'n_units_0': 108, 'n_units_1': 628, 'n_units_2': 146, 'n_units_3': 716, 'activation': 'relu'}
# Training Set - R²: 0.949, RMSE: 0.098, mean_ratio: 1.003, cov_ratio(%): 1.6
# Testing Set  - R²: 0.837, RMSE: 0.187, mean_ratio: 1.089, cov_ratio(%): 26.6
#
# Rank 6: Trial 65
# Parameters: {'n_layers': 4, 'n_units_0': 201, 'n_units_1': 828, 'n_units_2': 292, 'n_units_3': 540, 'activation': 'relu'}
# Training Set - R²: 0.949, RMSE: 0.098, mean_ratio: 1.012, cov_ratio(%): 1.6
# Testing Set  - R²: 0.837, RMSE: 0.187, mean_ratio: 1.128, cov_ratio(%): 30.2
#
# Rank 7: Trial 37
# Parameters: {'n_layers': 3, 'n_units_0': 315, 'n_units_1': 830, 'n_units_2': 526, 'activation': 'relu'}
# Training Set - R²: 0.949, RMSE: 0.099, mean_ratio: 1.011, cov_ratio(%): 1.7
# Testing Set  - R²: 0.828, RMSE: 0.192, mean_ratio: 1.073, cov_ratio(%): 27.8
#
# Rank 8: Trial 87
# Parameters: {'n_layers': 4, 'n_units_0': 147, 'n_units_1': 363, 'n_units_2': 335, 'n_units_3': 946, 'activation': 'relu'}
# Training Set - R²: 0.949, RMSE: 0.099, mean_ratio: 1.007, cov_ratio(%): 1.6
# Testing Set  - R²: 0.864, RMSE: 0.171, mean_ratio: 1.156, cov_ratio(%): 27.1
#
# Rank 9: Trial 64
# Parameters: {'n_layers': 3, 'n_units_0': 205, 'n_units_1': 985, 'n_units_2': 338, 'activation': 'relu'}
# Training Set - R²: 0.949, RMSE: 0.098, mean_ratio: 1.009, cov_ratio(%): 1.7
# Testing Set  - R²: 0.828, RMSE: 0.192, mean_ratio: 1.091, cov_ratio(%): 23.7
#
# Rank 10: Trial 58
# Parameters: {'n_layers': 4, 'n_units_0': 199, 'n_units_1': 717, 'n_units_2': 318, 'n_units_3': 831, 'activation': 'relu'}
# Training Set - R²: 0.949, RMSE: 0.098, mean_ratio: 1.010, cov_ratio(%): 1.6
# Testing Set  - R²: 0.851, RMSE: 0.179, mean_ratio: 1.102, cov_ratio(%): 28.6
